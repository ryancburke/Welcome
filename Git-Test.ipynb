# %%
gender1 = str(input("Please indicate your prefered title. Mr, Mrs, or Ms \n"))
name1 = str(input("I will keep that in mind. What is your first name?\n"))
name2 = str(input("Thank you. What is your last name?\n"))
print("Hello", gender1, name1, name2, ", it is very nice to meet you ")
age1 = int(input("Please indicate your age \n"))
if age1 <= 18:
  print("We require a minimum age of 18 years to access this content. Please come back in", 18 - age1, "years when you are old enough")
else:
  print("Welcome", gender1, name2)
